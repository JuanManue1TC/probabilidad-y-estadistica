# %% [markdown]
# <a href="https://colab.research.google.com/github/JuanManue1TC/probabilidad-y-estadistica/blob/main/Unidad1/PRACTICA_4_Y_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Probabilidad y estadistica
# unidad 1
# Grupo: 2z
# Practica 4 y 5. Tabla de frecuencias y regla de Sturges, Diagramas de Cajas y bigotes.
# Alumno:Juan Manuel Tarin Carrillo
#
# Docente: Dr: Jose Gabriel Rodriguez Rivas

# %%
import random
edades = []

# %%
for i in range (100):
  numero_aleatorio = random.randint( 18, 70)
  edades.append(numero_aleatorio)
print(edades)
# Out:
# [26, 51, 26, 24, 44, 41, 26, 44, 53, 49, 36, 54, 22, 55, 28, 48, 41, 29, 44, 23, 44, 44, 41, 61, 43, 37, 54, 48, 41, 42, 23, 42, 33, 60, 30, 21, 32, 50, 67, 66, 60, 43, 68, 36, 49, 26, 28, 22, 62, 22, 35, 39, 46, 35, 35, 66, 66, 67, 38, 54, 56, 35, 52, 23, 27, 66, 62, 31, 60, 24, 37, 32, 36, 48, 27, 27, 43, 27, 68, 23, 66, 33, 30, 42, 50, 70, 53, 63, 33, 30, 52, 56, 39, 64, 50, 18, 19, 27, 60, 53, 48, 55, 26, 46, 50, 18, 18, 19, 53, 31, 34, 66, 36, 26, 21, 54, 29, 57, 49, 27, 27, 32, 55, 42, 23, 37, 68, 59, 19, 41, 64, 68, 50, 69, 42, 26, 24, 59, 28, 39, 68, 51, 32, 19, 22, 26, 31, 67, 37, 28, 43, 26, 64, 20, 51, 28, 51, 70, 53, 38, 60, 51, 28, 31, 59, 55, 67, 62, 19, 37, 64, 37, 63, 70, 22, 24, 45, 62, 23, 62, 48, 19, 59, 32, 18, 45, 58, 41, 66, 51, 65, 28, 56, 43, 28, 56, 70, 37, 65, 32]

# %%
import pandas as pd
df = pd.DataFrame(edades,columns =['Edad'])
df.head()
# Out:
#    Edad
# 0    26
# 1    51
# 2    26
# 3    24
# 4    44

# %%
tabla_frecuencias = df['Edad'].value_counts().reset_index()
tabla_frecuencias.columns = ['Edad','Frecuencia']
tabla_frecuencias = tabla_frecuencias.sort_values(by='Edad')
print("Tabla de la Distribucion de frecuencias: ")
tabla_frecuencias
# Out:
# Tabla de la Distribucion de frecuencias:
#     Edad  Frecuencia
# 25    18           4
# 5     19           6
# 48    20           1
# 38    21           2
# 19    22           5
# 9     23           6
# 29    24           4
# 0     26           9
# 3     27           7
# 1     28           8
# 39    29           2
# 35    30           3
# 26    31           4
# 7     32           6
# 33    33           3
# 45    34           1
# 22    35           4
# 30    36           4
# 2     37           7
# 41    38           2
# 32    39           3
# 8     41           6
# 14    42           5
# 15    43           5
# 16    44           5
# 37    45           2
# 42    46           2
# 18    48           5
# 34    49           3
# 11    50           5
# 6     51           6
# 40    52           2
# 10    53           5
# 28    54           4
# 31    55           4
# 21    56           4
# 46    57           1
# 49    58           1
# 20    59           4
# 13    60           5
# ...

# %%
tabla_frecuencias['Frec relativa'] = tabla_frecuencias['Frecuencia']/100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec relativa
# 25    18           4           0.04
# 5     19           6           0.06
# 48    20           1           0.01
# 38    21           2           0.02
# 19    22           5           0.05
# 9     23           6           0.06
# 29    24           4           0.04
# 0     26           9           0.09
# 3     27           7           0.07
# 1     28           8           0.08
# 39    29           2           0.02
# 35    30           3           0.03
# 26    31           4           0.04
# 7     32           6           0.06
# 33    33           3           0.03
# 45    34           1           0.01
# 22    35           4           0.04
# 30    36           4           0.04
# 2     37           7           0.07
# 41    38           2           0.02
# 32    39           3           0.03
# 8     41           6           0.06
# 14    42           5           0.05
# 15    43           5           0.05
# 16    44           5           0.05
# ...

# %%
tabla_frecuencias['Frec porcentual'] = tabla_frecuencias['Frecuencia']/100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec relativa  Frec porcentual
# 25    18           4           0.04             0.04
# 5     19           6           0.06             0.06
# 48    20           1           0.01             0.01
# 38    21           2           0.02             0.02
# 19    22           5           0.05             0.05
# 9     23           6           0.06             0.06
# 29    24           4           0.04             0.04
# 0     26           9           0.09             0.09
# 3     27           7           0.07             0.07
# 1     28           8           0.08             0.08
# 39    29           2           0.02             0.02
# 35    30           3           0.03             0.03
# 26    31           4           0.04             0.04
# 7     32           6           0.06             0.06
# 33    33           3           0.03             0.03
# 45    34           1           0.01             0.01
# 22    35           4           0.04             0.04
# ...

# %%
tabla_frecuencias['Frec Acumulada'] = tabla_frecuencias['Frecuencia']. cumsum()
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec relativa  Frec porcentual  Frec Acumulada
# 25    18           4           0.04             0.04               4
# 5     19           6           0.06             0.06              10
# 48    20           1           0.01             0.01              11
# 38    21           2           0.02             0.02              13
# 19    22           5           0.05             0.05              18
# 9     23           6           0.06             0.06              24
# 29    24           4           0.04             0.04              28
# 0     26           9           0.09             0.09              37
# 3     27           7           0.07             0.07              44
# 1     28           8           0.08             0.08              52
# 39    29           2           0.02             0.02              54
# 35    30           3           0.03             0.03              57
# 26    31           4           0.04             0.04              61
# ...

# %%
import math
print (edades)
# Out:
# [26, 51, 26, 24, 44, 41, 26, 44, 53, 49, 36, 54, 22, 55, 28, 48, 41, 29, 44, 23, 44, 44, 41, 61, 43, 37, 54, 48, 41, 42, 23, 42, 33, 60, 30, 21, 32, 50, 67, 66, 60, 43, 68, 36, 49, 26, 28, 22, 62, 22, 35, 39, 46, 35, 35, 66, 66, 67, 38, 54, 56, 35, 52, 23, 27, 66, 62, 31, 60, 24, 37, 32, 36, 48, 27, 27, 43, 27, 68, 23, 66, 33, 30, 42, 50, 70, 53, 63, 33, 30, 52, 56, 39, 64, 50, 18, 19, 27, 60, 53, 48, 55, 26, 46, 50, 18, 18, 19, 53, 31, 34, 66, 36, 26, 21, 54, 29, 57, 49, 27, 27, 32, 55, 42, 23, 37, 68, 59, 19, 41, 64, 68, 50, 69, 42, 26, 24, 59, 28, 39, 68, 51, 32, 19, 22, 26, 31, 67, 37, 28, 43, 26, 64, 20, 51, 28, 51, 70, 53, 38, 60, 51, 28, 31, 59, 55, 67, 62, 19, 37, 64, 37, 63, 70, 22, 24, 45, 62, 23, 62, 48, 19, 59, 32, 18, 45, 58, 41, 66, 51, 65, 28, 56, 43, 28, 56, 70, 37, 65, 32]

# %%
import pandas as pd
df = pd.DataFrame({'Edad':edades})
df
# Out:
#      Edad
# 0      26
# 1      51
# 2      26
# 3      24
# 4      44
# ..    ...
# 195    56
# 196    70
# 197    37
# 198    65
# 199    32
#
# [200 rows x 1 columns]

# %%
n = len (edades)
k = int (1 + math.log2(100))
print ("Valor de n = ",n, "\nNumero de intervalos =",k)
# Out:
# Valor de n =  200
# Numero de intervalos = 7

# %%
tabla_frecuencias = pd.cut (df['Edad'], bins=k, include_lowest=True).value_counts().reset_index()
tabla_frecuencias.columns = ['clase','frec']
tabla_frecuencias
# Out:
#               clase  frec
# 0  (25.429, 32.857]    39
# 1  (47.714, 55.143]    34
# 2    (62.571, 70.0]    29
# 3  (17.947, 25.429]    28
# 4  (40.286, 47.714]    25
# 5  (32.857, 40.286]    24
# 6  (55.143, 62.571]    21

# %%
tabla_frecuencias = tabla_frecuencias.sort_values( by='clase')
tabla_frecuencias
# Out:
#               clase  frec
# 3  (17.947, 25.429]    28
# 0  (25.429, 32.857]    39
# 5  (32.857, 40.286]    24
# 4  (40.286, 47.714]    25
# 1  (47.714, 55.143]    34
# 6  (55.143, 62.571]    21
# 2    (62.571, 70.0]    29

# %%
tabla_frecuencias['frec Rel']= tabla_frecuencias['frec']/n
tabla_frecuencias['frec Porc']= tabla_frecuencias['frec']/n* 100
tabla_frecuencias['frec Ac']= tabla_frecuencias['frec'].cumsum()
tabla_frecuencias['frec Rel Ac']= tabla_frecuencias['frec Porc'].cumsum()
tabla_frecuencias['frec Porc Ac']= tabla_frecuencias['frec Porc'].cumsum()
print("Tabla de frecuencias: ")
tabla_frecuencias
# Out:
# Tabla de frecuencias:
#               clase  frec  frec Rel  frec Porc  frec Ac  frec Rel Ac  \
# 3  (17.947, 25.429]    28     0.140       14.0       28         14.0
# 0  (25.429, 32.857]    39     0.195       19.5       67         33.5
# 5  (32.857, 40.286]    24     0.120       12.0       91         45.5
# 4  (40.286, 47.714]    25     0.125       12.5      116         58.0
# 1  (47.714, 55.143]    34     0.170       17.0      150         75.0
# 6  (55.143, 62.571]    21     0.105       10.5      171         85.5
# 2    (62.571, 70.0]    29     0.145       14.5      200        100.0
#
#    frec Porc Ac
# 3          14.0
# 0          33.5
# 5          45.5
# 4          58.0
# 1          75.0
# 6          85.5
# 2         100.0

# %%
import matplotlib.pyplot as plt
plt.hist(edades,alpha=0.5,bins=20)
plt.title("Histrograma de edades basado en la funcion de matplotib con valores estandar")
# Out:
# Text(0.5, 1.0, 'Histrograma de edades basado en la funcion de matplotib con valores estandar')

# %%
plt.hist(df['Edad'],bins=k,alpha=0.5)
plt.title('Histograma de edades basado en la regla de sturges')
plt.xlabel('edades')
plt.xlabel('frecuencia')
# Out:
# Text(0.5, 0, 'frecuencia')

# %%
edades2 = []

for i in range (100):
  numero_aleatorio = random.randint( 20, 87)
  edades2.append(numero_aleatorio)
print(edades2)
# Out:
# [28, 84, 75, 52, 31, 60, 42, 66, 54, 50, 75, 60, 22, 25, 21, 50, 66, 43, 72, 57, 81, 54, 28, 41, 31, 84, 60, 31, 85, 79, 49, 35, 28, 28, 30, 73, 81, 80, 38, 73, 75, 32, 40, 31, 48, 56, 43, 54, 47, 20, 63, 22, 45, 74, 86, 55, 37, 33, 60, 25, 43, 65, 58, 55, 72, 77, 52, 64, 67, 33, 77, 49, 77, 43, 64, 63, 35, 70, 40, 84, 38, 61, 70, 48, 44, 57, 86, 86, 52, 62, 51, 46, 44, 82, 68, 38, 76, 25, 48, 76]

# %%
fig, (ax1,ax2) = plt.subplots(nrows=1, ncols=2, figsize=(9, 4))
bplot1 = ax1.boxplot(edades, vert=True, patch_artist=True)
ax1.set_title('Edades Encuesta 1')

bplot2 = ax2.boxplot(edades2, vert=True, patch_artist=True)
ax2.set_title('Edades Encuesta 2')
plt.show()

# %%
edades2.append(130)

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(9, 4))
bplot1 = ax1.boxplot(edades, vert=True, patch_artist=True)
ax1.set_title('Edades Encuesta 1')

bplot2 = ax2.boxplot(edades2, vert=True, patch_artist=True)
ax2.set_title('Edades Encuesta 2')
plt.show()
